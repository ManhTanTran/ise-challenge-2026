# %% [markdown]
# # Explore Data Lake
#
# Use this notebook to build and inspect the file index.

# %%
from pathlib import Path
import pandas as pd

from src.file_indexer import build_file_index

DATA_LAKE = Path('Data-Lake')
index = build_file_index(DATA_LAKE, 'outputs/file_index.json')
pd.DataFrame(index).head()
