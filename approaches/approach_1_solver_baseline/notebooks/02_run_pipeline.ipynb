# %% [markdown]
# # Run Pipeline
#
# Generate `outputs/submission.csv` from a question file and data lake.

# %%
from src.submission import generate_submission

generate_submission(
    question_path='0.Sample_Data.xlsx',
    data_lake_dir='Data-Lake',
    output_path='outputs/submission.csv',
    rebuild_index=False,
)
